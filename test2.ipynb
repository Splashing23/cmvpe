# %%
import pystac_client
import planetary_computer

catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)


time_range = "2020-12-01/2020-12-31"
bbox = [-95.462265, 29.676326, -95.262451, 29.815917]

search = catalog.search(collections=["naip"], bbox=bbox)
items = search.item_collection()
print(items.to_dict())



# area_of_interest = {
#     "type": "Polygon",
#     "coordinates": [
#         [
#             [-111.9839859008789, 40.5389819819361],
#             [-111.90502166748045, 40.5389819819361],
#             [-111.90502166748045, 40.57015381856105],
#             [-111.9839859008789, 40.57015381856105],
#             [-111.9839859008789, 40.5389819819361],
#         ]
#     ],
# }

# range_old = "2010-01-01/2013-01-01"
# range_new = "2018-01-01/2021-01-01"
# search_old = catalog.search(
#     collections=["naip"], intersects=area_of_interest, datetime=range_old
# )

# search_new = catalog.search(
#     collections=["naip"], intersects=area_of_interest, datetime=range_new
# )

# items_old = search_old.item_collection()
# items_new = search_new.item_collection()

# print(f"{len(items_old)} Items found in the 'old' range")
# print(f"{len(items_new)} Items found in the 'new' range")
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json'], 'id': 'tx_m_2909522_sw_15_060_20220914', 'geometry': {'type': 'Polygon', 'coordinates': [[[-95.307404, 29.622368], [-95.308991, 29.691868], [-95.379645, 29.690617], [-95.37801, 29.62112], [-95.307404, 29.622368]]]}, 'bbox': [-95.379645, 29.62112, -95.307404, 29.691868], 'properties': {'gsd': 0.6, 'datetime': '2022-09-14T16:00:00Z', 'naip:year': '2022', 'proj:bbox': [269746.2, 3279166.2, 276587.4, 3286873.2], 'proj:epsg': 26915, 'providers': [{'url': 'https://www.fsa.usda.gov/programs-and-services/aerial-photography/imagery-programs/naip-imagery/', 'name': 'USDA Farm Service Agency', 'roles': ['producer', 'licensor']}], 'naip:state': 'tx', 'proj:shape': [12845, 11402], 'proj:centroid': {'lat': 29.6565, 'lon': -95.34351}, 'proj:transform': [0.6, 0.0, 269746.2, 0.0, -0.6, 3286873.2, 0.0, 0.0, 1.0]}, 'links': [{'rel': 'collection', 'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/naip', 'type': 'application/json'}, {'rel': 'parent', 'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/naip', 'type': 'application/json'}, {'rel': 'root', 'href': 'https://planetarycomputer.microsoft.com/api/stac/v1', 'type': 'application/json', 'title': 'Microsoft Planetary Computer STAC API'}, {'rel': 'self', 'href': 'https://planetarycomputer.microsoft.com/api/stac/v1/collections/naip/items/tx_m_2909522_sw_15_060_20220914', 'type': 'application/geo+json'}, {'rel': 'preview', 'href': 'https://planetarycomputer.microsoft.com/api/data/v1/item/map?collection=naip&item=tx_m_2909522_sw_15_060_20220914', 'type': 'text/html', 'title': 'Map of item'}], 'assets': {'image': {'href': 'https://naipeuwest.blob.core.windows.net/naip/v002/tx/2022/tx_060cm_2022/29095/m_2909522_sw_15_060_20220914.tif?st=2025-01-13T15%3A43%3A35Z&se=2025-01-14T16%3A28%3A35Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-01-14T10%3A14%3A36Z&ske=2025-01-21T10%3A14%3A36Z&sks=b&skv=2024-05-04&sig=gaaPa9ZPLOO1PuemEetC77P6BlTdGXRmHCz/iXPuXq0%3D', 'type': 'image/tiff; application=geotiff; profile=cloud-optimized', 'title': 'RGBIR COG tile', 'eo:bands': [{'name': 'Red', 'common_name': 'red'}, {'name': 'Green', 'common_name': 'green'}, {'name': 'Blue', 'common_name': 'blue'}, {'name': 'NIR', 'common_name': 'nir', 'description': 'near-infrared'}], 'roles': ['data']}, 'thumbnail': {'href': 'https://naipeuwest.blob.core.windows.net/naip/v002/tx/2022/tx_060cm_2022/29095/m_2909522_sw_15_060_20220914.200.jpg?st=2025-01-13T15%3A43%3A35Z&se=2025-01-14T16%3A28%3A35Z&sp=rl&sv=2024-05-04&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2025-01-14T10%3A14%3A36Z&ske=2025-01-21T10%3A14%3A36Z&sks=b&skv=2024-05-04&sig=gaaPa9ZPLOO1PuemEetC77P6BlTdGXRmHCz/iXPuXq0%3D', 'type': 'image/jpeg', 'title': 'Thumbnail', 'roles': ['thumbnail']}, 'tilejson': {'href': 'https://planetarycomputer.microsoft.com/api/data/v1/item/tilejson.json?collection=naip&item=tx_m_2909522_sw_15_060_20220914&assets=image&asset_bidx=image%7C1%2C2%2C3&format=png', 'type': 'application/json', 'title': 'TileJSON with default rendering', 'roles': ['tiles']}, 'rendered_preview': {'href': 'https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=naip&item=tx_m_2909522_sw_15_060_20220914&assets=image&asset_bidx=image%7C1%2C2%2C3&format=png', 'type': 'image/png', 'title': 'Rendered preview', 'rel': 'preview', 'roles': ['overview']}}, 'collection': 'naip'}, {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json'], 'id': 'tx_m_2909522_se_15_060_20220914', 'geometry': {'type': 'Polygon', 'coordinates': [[[-9 ...

# %%
# from shapely.geometry import shape

# area_shape = shape(area_of_interest)
# target_area = area_shape.area


# def area_of_overlap(item):
#     overlap_area = shape(item.geometry).intersection(shape(area_of_interest)).area
#     return overlap_area / target_area


# item_old = sorted(items_old, key=area_of_overlap, reverse=True)[0]
# item_new = sorted(items_new, key=area_of_overlap, reverse=True)[0]

# %%
from IPython.display import Image

Image(url=items[5].assets["rendered_preview"].href)
# Out:
# <img src="https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=naip&item=tx_m_2909521_se_15_060_20220914&assets=image&asset_bidx=image%7C1%2C2%2C3&format=png"/>
